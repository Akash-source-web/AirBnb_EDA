# %% [markdown]
# # **Project Name**    - **AirBnb Bookings Analysis EDA**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Team Member**         - AKASH KUNDU

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world. Today, Airbnb became one of a kind service that is used and recognized by the whole world. Data analysis on millions of listings provided through Airbnb is a crucial factor for the company. These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services and much more. This dataset has around 49,000 observations in it with 16 columns and it is a mix of categorical and numeric values. Explore and analyse the data to discover key understandings.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Since 2008, guests and hosts have used Airbnb to expand on travelling possibilities and present a more unique, personalised way of experiencing the world.
# These millions of listings generate a lot of data - data that can be analysed and used for security, business decisions, understanding of customers' and providers' (hosts) behaviour and performance on the platform, guiding marketing initiatives, implementation of innovative additional services**

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1. Which is the prefered location according to average best price?
# 2. Where are most of the hosts located?
# 3. The highest and lowest rent paying locations by customers
# 4. Most Popular/demanded host based on reviews and availability 365 days
# 5. Establishing relation between neighbourhood group and availability of rooms.
# 6. What we learn about diffrent hosts and areas?
# 7. Room type selection based on price, availability on 365 days.
# 8. Top ten neighbourhood based on listing price.
# 9. Distribution of properties based on Mandatory stays.
# 10. Type of Visit based on Mandatory stay allowed for single booking.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd  #library use for data manipulation
import numpy as np   #library use for Statastics Calculation
import matplotlib.pyplot as plt   #library use for Vizualization
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
# Connation stablishment with Google drive for the dataset
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
airbnb = pd.read_csv('Airbnb NYC 2019.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
airbnb.head()  #display the first five rows of dataset
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
airbnb.shape
# Out:
# (48895, 16)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
airbnb.info() #use to check for the datatype of column data and also cheak for the null value.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
airbnb.duplicated().sum()
# Out:
# 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
airbnb.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(10,6))
sns.heatmap(airbnb.isna(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# Airbnb Dataset has (48895, 16) rows X columns and have maximum missing values in the two column only which is last_review and reviews_per_month and the count or these missing values is 10052 same represented in the above heatmap.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
airbnb.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='object')

# %%
# Dataset Describe
airbnb.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  4.889500e+04  4.889500e+04  48895.000000  48895.000000  48895.000000
# mean   1.901714e+07  6.762001e+07     40.728949    -73.952170    152.720687
# std    1.098311e+07  7.861097e+07      0.054530      0.046157    240.154170
# min    2.539000e+03  2.438000e+03     40.499790    -74.244420      0.000000
# 25%    9.471945e+06  7.822033e+06     40.690100    -73.983070     69.000000
# 50%    1.967728e+07  3.079382e+07     40.723070    -73.955680    106.000000
# 75%    2.915218e+07  1.074344e+08     40.763115    -73.936275    175.000000
# max    3.648724e+07  2.743213e+08     40.913060    -73.712990  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    48895.000000       48895.000000       38843.000000
# mean         7.029962          23.274466           1.373221
# std         20.510550          44.550582           1.680442
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# This dataset contains 16 features/variables about Airbnb listings within New York City. Below are the features with their descriptions:
# 1.  id: Listing ID (numeric variable)
# 2.  name: Listing Title (categorical variable)
# 3.  host_id: ID of Host (numeric variable)
# 4.  host_name: Name of Host (categorical Variable)
# 5.  neighbourhood_group: Neighbourhood group that contains listing (categorical variable)
# 6.  neighbourhood: Neighbourhood group that contains listing (categorical variable)
# 7.  latitude: Latitude of listing (numeric variable)
# 8.  longitude: Longitude of listing (numeric variable)
# 9.  room_type: Type of the offered property (categorical variable)
# 10. price: Price per night in USD (numeric variable)
# 11. minimum_nights: Minimum number of nights required to book listing (numeric variable)
# 12. number_of_reviews: Total number of reviews that listing has (numeric variable)
# 13. last_review: Last rent date of the listing (date variable)
# 14. reviews_per_month: Total number of reviews divided by the number of months that the listing is active (numeric variable)
# 15. calculated_host_listings_count: Amount of listing per host (numeric variable)
# 16. availability_365: Number of days per year the listing is active (numeric variable)

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in airbnb.columns:
    unique_values = airbnb[column].unique()
    print(f"Unique values for {column}:", unique_values)
# Out:
# Unique values for id: [    2539     2595     3647 ... 36485431 36485609 36487245]
# Unique values for name: ['Clean & quiet apt home by the park' 'Skylit Midtown Castle'
#  'THE VILLAGE OF HARLEM....NEW YORK !' ...
#  'Sunny Studio at Historical Neighborhood'
#  '43rd St. Time Square-cozy single bed'
#  "Trendy duplex in the very heart of Hell's Kitchen"]
# Unique values for host_id: [     2787      2845      4632 ... 274321313  23492952  68119814]
# Unique values for host_name: ['John' 'Jennifer' 'Elisabeth' ... 'Abayomi' 'Alberth' 'Ilgar & Aysel']
# Unique values for neighbourhood_group: ['Brooklyn' 'Manhattan' 'Queens' 'Staten Island' 'Bronx']
# Unique values for neighbourhood: ['Kensington' 'Midtown' 'Harlem' 'Clinton Hill' 'East Harlem'
#  'Murray Hill' 'Bedford-Stuyvesant' "Hell's Kitchen" 'Upper West Side'
#  'Chinatown' 'South Slope' 'West Village' 'Williamsburg' 'Fort Greene'
#  'Chelsea' 'Crown Heights' 'Park Slope' 'Windsor Terrace' 'Inwood'
# ...

# %%
#total number of unique values present in each column
unique_counts = airbnb.nunique()
print("Number of unique values for each column:")
print(unique_counts)
# Out:
# Number of unique values for each column:
# id                                48895
# name                              47905
# host_id                           37457
# host_name                         11452
# neighbourhood_group                   5
# neighbourhood                       221
# latitude                          19048
# longitude                         14718
# room_type                             3
# price                               674
# minimum_nights                      109
# number_of_reviews                   394
# last_review                        1764
# reviews_per_month                   937
# calculated_host_listings_count       47
# availability_365                    366
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
# Droping unnessesary columns
airbnb.drop(['id', 'last_review'], axis = 1, inplace=True)
airbnb.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
#impute the null value for the nessesary columns
airbnb.fillna({'reviews_per_month':0},inplace=True)
airbnb.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Deleted the unnessesary column which are ('last_review','reviews_per_month'). Because column contain too many missing values 10050 to be exact which make the totaly use less.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
#Count of property according to areas
sns.countplot(airbnb['neighbourhood_group'], palette="plasma")
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.title('Neighbourhood Group')
# Out:
# C:\Users\akund\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Neighbourhood Group')

# %% [markdown]
# #### Chart - 1

# %% [markdown]
# ### **Q1.**What we learn about diffrent hosts and areas?

# %%
areas_hosts = airbnb.groupby(['host_name', 'neighbourhood_group'])['calculated_host_listings_count'].max().reset_index()
areas_hosts.sort_values(by= 'calculated_host_listings_count',ascending=False).head()
# Out:
#           host_name neighbourhood_group  calculated_host_listings_count
# 13217  Sonder (NYC)           Manhattan                             327
# 1834     Blueground           Manhattan                             232
# 1833     Blueground            Brooklyn                             232
# 7275           Kara           Manhattan                             121
# 7480         Kazuya              Queens                             103

# %%
fig = plt.figure(figsize = (5,5))
sns.histplot(data = areas_hosts)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I choose Histogram becouse the usibilty of the chart for the distribution of the data and also use for the continuous data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insight founded from the above chart is that the maximum number of host counted between 1-30 which means that maximum hosts host only 1-30 guests and only few which host more then 200. Which tells us were the maximim number of guest are comming and where we need to focus more and help to set the price for the same accordingly.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes it help to analyse the most profit area and least profit area

# %% [markdown]
# #### Chart - 2

# %% [markdown]
# ### **Q2.**What we have learn from room type and their prices according to area?

# %%
room_price_area = airbnb.groupby(['neighbourhood_group', 'room_type'])['price'].max().reset_index()
room_price_area.sort_values(by = 'price', ascending=False).head()
# Out:
#    neighbourhood_group        room_type  price
# 3             Brooklyn  Entire home/apt  10000
# 6            Manhattan  Entire home/apt  10000
# 10              Queens     Private room  10000
# 7            Manhattan     Private room   9999
# 4             Brooklyn     Private room   7500

# %%
# Chart - 2 visualization code
neighbourhood_group = ['Brooklyn', 'Manhattan', 'Queens', 'Manhattan', 'Brooklyn', 'Staten Island', 'Queens', 'Bronx', 'Queens', 'Bronx']
room_type = ['Entire home/apt', 'Entire home/apt', 'Private room', 'Private room', 'Private room', 'Entire home/apt', 'Entire home/apt', 'Private room', 'Shared room', 'Entire home/apt']

room_dict = {} #Create a dictionary named room_dict to store the count of each room type. Loop through the room_type list and increase the count of the room type in the dictionary if it already exists. If not, add the room type as a key with the count as 1.


for i in room_type:
  room_dict[i] = room_dict.get(i,0) + 1

plt.bar(room_dict.keys(), room_dict.values(), color = 'orange', edgecolor = 'black')
plt.title('Room Type and their Count')
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Beacouse I have the data in catagorical form and also I need the count of diffrent type of room .

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights got that **Entire home/apt** have the highest number to room count and have the highest price in **Brooklyn, Manhattan** for that.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact is that from here we can identify the room type from where we get more revenue.

# %% [markdown]
# #### Chart - 3

# %% [markdown]
# ### **Q3.** What we can learn from the data? (Ex. reviews, locations, price, etc. )

# %%
#Data contain total number of reviews we get from each area
area_review = airbnb.groupby(['neighbourhood_group'])['number_of_reviews'].max().reset_index()
area_review.sort_values(by = 'number_of_reviews', ascending= False)
# Out:
#   neighbourhood_group  number_of_reviews
# 3              Queens                629
# 2           Manhattan                607
# 1            Brooklyn                488
# 4       Staten Island                333
# 0               Bronx                321

# %%
# Chart - 3 visualization code
area = area_review['neighbourhood_group']
review = area_review['number_of_reviews']

fig = plt.figure(figsize = (7,5))
plt.bar(area, review, color = '#8A2BE2', edgecolor = '#000000')
plt.title('Review count with respect to area')
plt.xlabel('Area')
plt.ylabel('Review Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because of Catagoricale data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We are getting maximum number of reviews from **Queens** Area or we can say that in this area we have some active customers.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Positive impact for this insight is from the review we can found the activity of our users and can also found the improvement area which are suggested into the reviews.

# %% [markdown]
# #### Chart - 4

# %%
# Data contain price and total number of reviews relations
price_review_data = airbnb.groupby(['price'])['number_of_reviews'].max().reset_index()
price_review_data.sort_values(by = 'number_of_reviews', ascending=False).head()
# Out:
#     price  number_of_reviews
# 36     47                629
# 38     49                607
# 35     46                543
# 88     99                540
# 37     48                510

# %%
# Chart - 4 visualization code
price = price_review_data['price']
review_count = price_review_data['number_of_reviews']

plt.scatter(price, review_count)
plt.title('Price VS No_of_reviews')
plt.xlabel('Price')
plt.ylabel('Review Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because we want to see the coorelation between price and reviews count.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# People paying lowest price are given highest number of reviews.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 5

# %% [markdown]
# ### **Q4.** Which host is the busiest and what is the reason?

# %%
#Data that contain the busiest host i.e. the host entertain most number of guest we calculated it with the help of review given to it.
busy_host = airbnb.groupby(['host_id', 'host_name', 'room_type'])['number_of_reviews'].max().reset_index()
busy_host = busy_host.sort_values(by= 'number_of_reviews', ascending=False).head(10)
busy_host
# Out:
#         host_id host_name        room_type  number_of_reviews
# 24484  47621202      Dona     Private room                629
# 7707    4734398        Jj     Private room                607
# 22213  37312959      Maya     Private room                543
# 4590    2369681     Carol     Private room                540
# 19443  26432133  Danielle     Private room                510
# 13707  12949460       Asa  Entire home/apt                488
# 1974     792159     Wanda     Private room                480
# 5056    2680820     Linda     Private room                474
# 161       42273      Dani  Entire home/apt                467
# 18289  23591164    Angela     Private room                466

# %%
# Chart - 5 visualization code
host = busy_host['host_name']
review_count = busy_host['number_of_reviews']

plt.bar(host, review_count, color = '#EE4000', edgecolor = '#000000', width = 0.5)
plt.title('Busiest Host')
plt.xlabel('Host')
plt.ylabel('Review Count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I want data in catagorical form.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most busy host is **Dona**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Host on which give us most revenue.

# %% [markdown]
# #### Chart - 6

# %% [markdown]
# ### **Q5.** Which host are charging the highest price?

# %%
#Data Contain the host which charges the highest fair for their residence.
highest_fair = airbnb.groupby(['host_id', 'host_name','room_type', 'neighbourhood_group'])['price'].max().reset_index()
highest_fair = highest_fair.sort_values(by = 'price', ascending=False).head(10)
highest_fair
# Out:
#          host_id host_name        room_type neighbourhood_group  price
# 27920   72390391    Jelena  Entire home/apt           Manhattan  10000
# 17060   20582832  Kathrine     Private room              Queens  10000
# 8055     5143901      Erin  Entire home/apt            Brooklyn  10000
# 7325     4382127      Matt  Entire home/apt           Manhattan   9999
# 2659     1235070     Olson  Entire home/apt           Manhattan   9999
# 6628     3906464       Amy     Private room           Manhattan   9999
# 16096   18128455       Rum  Entire home/apt           Manhattan   8500
# 2561     1177497   Jessica  Entire home/apt            Brooklyn   8000
# 33424  156158778     Sally  Entire home/apt           Manhattan   7703
# 10113    7407743      Jack  Entire home/apt           Manhattan   7500

# %%
# Chart - 6 visualization code
name_host = highest_fair['host_name']
property_price = highest_fair['price']

plt.bar(name_host, property_price, color = '#CD0000', edgecolor = '#000000', width = 0.5)
plt.title('Price Distribution of Properties')
plt.xlabel('Host Name')
plt.ylabel('property_price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To show the distribution of the price

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Properties belonging to **Manhatten, Broklyn, Queens** have the highest fare which is **1000 each** and owner holding these properties named as **Jelena, Kathrine, Erin**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insight we get is that the revnue we got most from these and these property are also more premium and negative impact can be that because of high price less people book the property so  the idel time is more.

# %% [markdown]
# #### Chart - 7

# %% [markdown]
# ### **Q6.**Is their any fare diffrence among diffrent areas and what could be the reason?

# %%
airbnb.head()
# Out:
#                                                name  host_id    host_name  \
# 0                Clean & quiet apt home by the park     2787         John
# 1                             Skylit Midtown Castle     2845     Jennifer
# 2               THE VILLAGE OF HARLEM....NEW YORK !     4632    Elisabeth
# 3                   Cozy Entire Floor of Brownstone     4869  LisaRoxanne
# 4  Entire Apt: Spacious Studio/Loft by central park     7192        Laura
#
#   neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 0            Brooklyn    Kensington  40.64749  -73.97237     Private room
# 1           Manhattan       Midtown  40.75362  -73.98377  Entire home/apt
# 2           Manhattan        Harlem  40.80902  -73.94190     Private room
# 3            Brooklyn  Clinton Hill  40.68514  -73.95976  Entire home/apt
# 4           Manhattan   East Harlem  40.79851  -73.94399  Entire home/apt
#
#    price  minimum_nights  number_of_reviews  reviews_per_month  \
# ...

# %%
# Data prepration for the fare diffrence among areas to find out the reason behind the diffrence.
area_fare = airbnb.groupby(['neighbourhood_group','room_type'])['minimum_nights'].count().reset_index()
area_fare = area_fare.sort_values(by = 'minimum_nights', ascending= False)
area_fare
# Out:
#    neighbourhood_group        room_type  minimum_nights
# 6            Manhattan  Entire home/apt           13199
# 4             Brooklyn     Private room           10132
# 3             Brooklyn  Entire home/apt            9559
# 7            Manhattan     Private room            7982
# 10              Queens     Private room            3372
# 9               Queens  Entire home/apt            2096
# 1                Bronx     Private room             652
# 8            Manhattan      Shared room             480
# 5             Brooklyn      Shared room             413
# 0                Bronx  Entire home/apt             379
# 11              Queens      Shared room             198
# 13       Staten Island     Private room             188
# 12       Staten Island  Entire home/apt             176
# 2                Bronx      Shared room              60
# 14       Staten Island      Shared room               9

# %%
# Chart - 7 visualization code
property_area = area_fare['neighbourhood_group']
booking_count = area_fare['minimum_nights']


plt.bar(property_area, booking_count, color = '#CD0000', edgecolor = '#000000', width = 0.5)
plt.title('Area with count of booking')
plt.xlabel('Area Name')
plt.ylabel('Count of the booking')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because it help to distinguese the diffrent area sepratly

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# **Manhattan** have high number of bookings.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Even manhattan have the highest price then also we got the highest booking from that area i.e. it is the most visited place and have the potential to grow more .

# %% [markdown]
# #### Chart - 8

# %% [markdown]
# ### **Q7**. Availablity of proprities accordig to their location.

# %%
# Chart - 8 visualization code
plt.figure(figsize=(10,6))
sns.scatterplot(x = airbnb['longitude'],y = airbnb['latitude'],hue=airbnb['neighbourhood_group'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the exact location of the proprities around the city.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that less property we have in **Stateb Island, Bronx**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Accourding to the findings of the data we come up with the redolution that we need to increase the property in the places where they are very less.

# %% [markdown]
# #### Chart - 9

# %% [markdown]
# ### **Q8.** Availablity of the room in the neighbouring group around the year.

# %%
# Chart - 9 visualization code
plt.figure(figsize=(10,10))
ax = sns.boxplot(data=airbnb, x='neighbourhood_group',y='availability_365',palette='plasma')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see that the is their any group which is extrimily available or not.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# We found that **Quens** is the group which is most of the year available.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# #### Chart - 10

# %% [markdown]
# ### **Q9.** Distribution of neighbour group based on minimum number of stay allowed on single booking.

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10,6))
sns.barplot(x = airbnb['neighbourhood_group'], y = airbnb['minimum_nights'])
plt.ylim(1, 10)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to get the exact no of nights per group

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see maximum number of groups ask for minimum 5 nights stay on single booking

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Insights we get that even after the mandate 5 nights people stays in manhattan

# %% [markdown]
# #### Chart - 11

# %% [markdown]
# ### **Q10.** Number of nights distribution over all groups according to the price.

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10,6))
sns.scatterplot(x = airbnb['price'],y = airbnb['minimum_nights'],hue=airbnb['neighbourhood_group'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# to see the distribution of the price and nights

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Even after manhatten is a expensive property and high minimum stay count it is performing very good.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Manhatten is the property which gives us high revenue.

# %% [markdown]
# #### Chart - 12

# %% [markdown]
# ### **Q11.** Distribution of room type around the all neighbour group.

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,6))
sns.scatterplot(x = airbnb['longitude'],y = airbnb['latitude'],hue=airbnb['room_type'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To get the spread of the rooms over all the cities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Insights we get is that the type of rooms we get to see more is **Private Room**

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The clint have the most room of private type means we need to focus on the private room more because people like to book them most to get more indipendency.

# %% [markdown]
# #### Chart - 13

# %% [markdown]
# ### **Q12.** Check for the Room Type availablity.

# %%
# Chart - 13 visualization code
plt.figure(figsize=(10,6))
sns.barplot(x = airbnb['room_type'], y = airbnb['availability_365'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To decode the availablity of the rooms through out the year according to their room type.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see most room type which are available most of the time are **Shared room** which is obeous because less people book for shared room.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# No

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %% [markdown]
# ### **Q13.** Correlation between diffrent variables.

# %%
# Correlation Heatmap visualization code
fig = plt.figure(figsize=(10,5))
Corr = airbnb.corr(method='kendall')
sns.heatmap(Corr,annot=True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see the corelation between diffrent variable of data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Their is a high correlation between **host listing count** AND **availablity** more the listing more the chance of availablity.

# %% [markdown]
# #### Chart 15

# %% [markdown]
# ### **Q14.** What is the room count in overall NYC according to the listing of room types?

# %%
plt.rcParams['figure.figsize'] = (8, 5)
ax= sns.countplot(y='room_type',hue='neighbourhood_group',data=airbnb,palette='bright')

total = len(airbnb['room_type'])
for p in ax.patches:
        percentage = '{:.1f}%'.format(100 * p.get_width()/total)
        x = p.get_x() + p.get_width() + 0.02
        y = p.get_y() + p.get_height()/2
        ax.annotate(percentage, (x, y))

plt.title('Count of each room types in NYC')
plt.xlabel('Rooms')
plt.xticks(rotation=90)
plt.ylabel('Room Counts')

plt.show()

# %% [markdown]
# #### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# As we can see most of the **Entire home/apt** are available in **Manhattan** and **Private room** available in **Brooklyn**

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization code
sns.pairplot(airbnb)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To see the pairwise relationship between variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# **Limitations & Scope of Improvement**
#
# 1. Datasets have limiting attributes to classify various categories of properties.
# 2. Customer experiential and Category wise ratings for Hosts seemed to be missing which could have played an important role in identifying Star Hosts.
# 3. A lot of guest information were missing like Purpose of Visit, Number of Guests, which could have given a sense of understanding about the relation of customer footfall and neighbourhoods.
# 4. Key attributes of properties like Number of Beds, Closets, Bathrooms, Gym, Sauna, Property Age, Distances from nearest Hospitals, Shopping Complexes, Airport, Station were missing.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# 1. Manhattan and Brooklyn are the posh areas in NY as there is maximum footfall and properties based on prices and listings are are on the higher side.
# 2. Manhattan and Brooklyn have the highest number of hosts.
# 3. Manhattan has highest number of Private rooms and Entire House/Apt. in culmination followed by Brooklyn.
# 4. Highest accommodations of 10,000 USD are available in Manhattan, Brooklyn and Queens.
# 5. Most popular hosts are Sonder, Blueground, Kara to name a few based on number of reviews and calculated host listing counts.
# 6. Staten Island seems more available for booking throughout the year compared to other neighbourhoods.
#
# 7. Sonder,Blueground,Sally are some of the top hosts based on their turnover.
# 8. Financial District, Midtown, Chelsea are some of the top neighbourhood based on their turnover.
# 9. Shared rooms are mostly available over other room types and Entire Home /Apt which has the highest proportion of room share are mostly on the expensive ends.
# 10. Fort Wadsworth and Woodrow are expensive neighbourhood based on median listed price belonging to Staten Island.
# 11. Most hosts allow a minimum 5 nights mandatory stay for single booking but the average increases in case of Manhattan, Brooklyn and Queens.
# 12. Bronx and Staten Island are mostly preferred for Shorter SCREENCADY Visits and onwards and others are for slightly longer stays.
#
#
# **Marketing Initiative**
# 1. Manhattan being the star neighbourhood we can roll down a lot of festive offers encouraging longer stays during Christmas and coming up with loyalty cards for frequent visitors which can also work for Brooklyn and Queens.
# 2. The star hosts should be incentivised to encourage them to maintain the properties and services as per the company standards.
# 3. Staten Island and Bronx can have discounts encouraging students to stay for a longer period. It can also have frequent check in cards for people from low income groups visiting regularly by offering good incentives and coupons.
# 4. Some local tours can be clubbed during longer visits encouraging customers to stay longer and prefer their stays.
#
# **Key Takeaways**
# 1. Festive Offers and Loyalty Cards
# 2. Discounts and Frequent Check In Cards
# 3. Incentivising Hosts
# 4. Local tours and experiences

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
